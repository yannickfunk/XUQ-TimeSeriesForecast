# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
EXP_NAME = "sinus_peak_noise_valley_noise_conditional_lstm"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "scale_attributions_38.png"

# %%
attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

# %%
for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()

# %%
EXP_NAME = "sinus_peak_spike_valley_noise_conditional_lstm"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "scale_attributions_38.png"

attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()

# %%
EXP_NAME = "sinus_peak_spike_amplitude_nhits_exogenous"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "scale_attributions_32.png"

attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()

# %%
EXP_NAME = "sinus_peak_spike_amplitude_nhits_exogenous"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "loc_attributions_12.png"

attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()

# %%
EXP_NAME = "sinus_peak_spike_nhits_exogenous"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "scale_attributions_8.png"

attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()

# %%
EXP_NAME = "sinus_peak_spike_nhits_exogenous"
RESULTS_PATH = Path("../experiments") / EXP_NAME / "results"
POINT_TO_EXPLAIN = "scale_attributions_28.png"

attr_methods = [e for e in os.listdir(RESULTS_PATH) if not e.endswith(".png")]

for method in attr_methods:
    img = imread(RESULTS_PATH / method / POINT_TO_EXPLAIN)
    plt.imshow(img)
    plt.show()
